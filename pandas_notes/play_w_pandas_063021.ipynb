# %%
import pandas
import pandas as pd
pd.set_option('display.max_rows', 1000)

# %%
pandas.__version__
# Out:
# '1.1.5'

# %%
pandas.read_csv('data/gapminder.tsv', sep='\t')
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df = pandas.read_csv('data/gapminder.tsv', sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
#import typing
#from typing import int
df.head(n=10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
df.tail(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
country = df['country']

# %%
type(country)
# Out:
# pandas.core.series.Series

# %%
country = df[['country']]

# %%
type(country)
# Out:
# pandas.core.frame.DataFrame

# %%
df.drop(['continent'], axis = 'columns')
# Out:
#           country  year  lifeExp       pop   gdpPercap
# 0     Afghanistan  1952   28.801   8425333  779.445314
# 1     Afghanistan  1957   30.332   9240934  820.853030
# 2     Afghanistan  1962   31.997  10267083  853.100710
# 3     Afghanistan  1967   34.020  11537966  836.197138
# 4     Afghanistan  1972   36.088  13079460  739.981106
# ...           ...   ...      ...       ...         ...
# 1699     Zimbabwe  1987   62.351   9216418  706.157306
# 1700     Zimbabwe  1992   60.377  10704340  693.420786
# 1701     Zimbabwe  1997   46.809  11404948  792.449960
# 1702     Zimbabwe  2002   39.989  11926563  672.038623
# 1703     Zimbabwe  2007   43.487  12311143  469.709298
#
# [1704 rows x 5 columns]

# %%
df.loc[[0,1]]
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030

# %%
df.iloc[[0,1,-1]]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.iloc[::-20]
# Out:
#                        country continent  year  lifeExp        pop  \
# 1703                  Zimbabwe    Africa  2007   43.487   12311143
# 1683                    Zambia    Africa  1967   47.768    3900000
# 1663        West Bank and Gaza      Asia  1987   67.046    1691210
# 1643                 Venezuela  Americas  2007   73.747   26084662
# 1623                   Uruguay  Americas  1967   68.468    2748579
# 1603            United Kingdom    Europe  1987   75.007   56981620
# 1583                    Turkey    Europe  2007   71.777   71158647
# 1563                   Tunisia    Africa  1967   52.053    4786986
# 1543                      Togo    Africa  1987   56.941    3154264
# 1523                  Tanzania    Africa  2007   52.517   38139640
# 1503                    Taiwan      Asia  1967   67.500   13648692
# 1483               Switzerland    Europe  1987   77.410    6649942
# 1463                 Swaziland    Africa  2007   39.613    1133066
# ...

# %%
subset = df.loc[:,['year','pop']]

# %%
subset
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %%
df.loc[df['country'] == 'United States']
# Out:
#             country continent  year  lifeExp        pop    gdpPercap
# 1608  United States  Americas  1952   68.440  157553000  13990.48208
# 1609  United States  Americas  1957   69.490  171984000  14847.12712
# 1610  United States  Americas  1962   70.210  186538000  16173.14586
# 1611  United States  Americas  1967   70.760  198712000  19530.36557
# 1612  United States  Americas  1972   71.340  209896000  21806.03594
# 1613  United States  Americas  1977   73.380  220239000  24072.63213
# 1614  United States  Americas  1982   74.650  232187835  25009.55914
# 1615  United States  Americas  1987   75.020  242803533  29884.35041
# 1616  United States  Americas  1992   76.090  256894189  32003.93224
# 1617  United States  Americas  1997   76.810  272911760  35767.43303
# 1618  United States  Americas  2002   77.310  287675526  39097.09955
# 1619  United States  Americas  2007   78.242  301139947  42951.65309

# %%
df.loc[(df['country'] == 'United States') & (df['year'] == 1982)]
# Out:
#             country continent  year  lifeExp        pop    gdpPercap
# 1614  United States  Americas  1982    74.65  232187835  25009.55914

# %%
df.groupby(['continent'])['lifeExp'].mean().round(0).to_frame().sort_values(by=['lifeExp'],ascending=False)
# Out:
#            lifeExp
# continent
# Oceania       74.0
# Europe        72.0
# Americas      65.0
# Asia          60.0
# Africa        49.0

# %%
df.groupby(['year'])['lifeExp'].median().round(2).to_frame()
# Out:
#       lifeExp
# year
# 1952    45.14
# 1957    48.36
# 1962    50.88
# 1967    53.82
# 1972    56.53
# 1977    59.67
# 1982    62.44
# 1987    65.83
# 1992    67.70
# 1997    69.39
# 2002    70.83
# 2007    71.94

# %%
df.loc[(df['continent'] == 'Americas')]
# Out:
#                   country continent  year  lifeExp        pop     gdpPercap
# 48              Argentina  Americas  1952   62.485   17876956   5911.315053
# 49              Argentina  Americas  1957   64.399   19610538   6856.856212
# 50              Argentina  Americas  1962   65.142   21283783   7133.166023
# 51              Argentina  Americas  1967   65.634   22934225   8052.953021
# 52              Argentina  Americas  1972   67.065   24779799   9443.038526
# 53              Argentina  Americas  1977   68.481   26983828  10079.026740
# 54              Argentina  Americas  1982   69.942   29341374   8997.897412
# 55              Argentina  Americas  1987   70.774   31620918   9139.671389
# 56              Argentina  Americas  1992   71.868   33958947   9308.418710
# 57              Argentina  Americas  1997   73.275   36203463  10967.281950
# 58              Argentina  Americas  2002   74.340   38331121   8797.640716
# ...

# %%
df.loc[(df['continent'] == 'Americas')].groupby(['year'])['lifeExp'].median().round(2).to_frame()
# Out:
#       lifeExp
# year
# 1952    54.74
# 1957    56.07
# 1962    58.30
# 1967    60.52
# 1972    63.44
# 1977    66.35
# 1982    67.40
# 1987    69.50
# 1992    69.86
# 1997    72.15
# 2002    72.05
# 2007    72.90

# %%
import numpy as np
df.groupby(['year'])['lifeExp'].agg(np.mean).round(2)
# Out:
# year
# 1952    49.06
# 1957    51.51
# 1962    53.61
# 1967    55.68
# 1972    57.65
# 1977    59.57
# 1982    61.53
# 1987    63.21
# 1992    64.16
# 1997    65.01
# 2002    65.69
# 2007    67.01
# Name: lifeExp, dtype: float64

# %%
42 min
# Out:
#   File "<ipython-input-31-649118d69a6b>", line 1
#     42 min
#          ^
# SyntaxError: invalid syntax
